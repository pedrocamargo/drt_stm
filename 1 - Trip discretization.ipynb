# %%
import openmatrix as omx
import os
import numpy as np
import pandas as pd
import sys
import random
from scipy.sparse import coo_matrix
import logging as logger
import sqlite3

# %%
logger.basicConfig(format='%(asctime)s %(levelname)-8s %(message)s',
                   level=logger.INFO,
                   datefmt='%Y-%m-%d %H:%M:%S')

# %%
fldr = "C:/D/Projects/Vancouver"
outdb = sqlite3.connect(os.path.join(fldr, 'trip_table.sqlite'))

# %% [markdown]
# In order to not require the Emme License while discretizing trips, we have exported all the matrices into a single OMX container

# %%
matrices = "matrices.omx"
omx_file = os.path.join(fldr, matrices)
matrices = omx.open_file(omx_file, 'r')

# %%
# matrices.close()

# %%
# We collect the mapping information for zone numbers
tazs = matrices.mapping('taz')
tazs = np.array(list(tazs.keys()))
max_zone = tazs.max()

# %%
all_mats = matrices.list_matrices()

# %% [markdown]
# The actual function to discretize a given matrix

# %%
def discretize_matrix(matrix, zones, total_diff=50, zonal_difference=5, tries=100):
    diff = 100
    best_trial = None
    best_diff = 1000000000
    tot_diff = 100000000
    
    q = coo_matrix(matrix)
    
    orig_data = pd.DataFrame({'rows':tazs[q.row], 'cols':tazs[q.col], "class":[m]* q.data.shape[0], "flow":q.data})
    orig_prod = orig_data.groupby(['rows']).sum()[["flow"]]
    orig_prod.columns = ['original']
    orig_dest = orig_data.groupby(['cols']).sum()[["flow"]]
    orig_dest.columns = ['original']
    tot_trips = q.sum()
    for tried in range(tries):
        df = orig_data.copy()

        dfs = []

        int_part = np.modf(df[df.flow>1].flow.values)[1]
        df1 = pd.DataFrame(df[df.flow >= 1])
        df1.flow = int_part
        df.loc[df.flow>1, "flow"] -= int_part[:]
        dfs.append(df1)
        df = df.assign(expected=np.random.rand(df.shape[0]))
        df = df[df.expected < df.flow]
        df.flow = 1
        df.drop(['expected'], axis=1, inplace=True)
        dfs.append(df)
        df = pd.concat(dfs, ignore_index=True)
        df = df.reindex(df.index.repeat(df.flow.astype(np.int)))
        df.flow = 1

        # Compute the differences
        prod = df.groupby(['rows']).sum()[["flow"]]    
        dest = df.groupby(['cols']).sum()[["flow"]]
        
        diffp = orig_prod.join(prod).fillna(0)
        diffp = abs(diffp.original.values - diffp.flow.values)
        if not diffp.shape[0]:
            continue
        diffp = diffp.max()
        diffa = orig_dest.join(dest).fillna(0)
        diffa = abs(diffa.original.values - diffa.flow.values)
        if not diffa.shape[0]:
            continue
        diffa = diffa.max()
        
        # max difference for a zone
        diff = max(diffp, diffa)
        
        # Difference in totals
        tdf = abs(df.flow.values.sum() - tot_trips)
        
        # If we still have differences that  are too big
        if tot_diff > total_diff:
            if tot_diff > tdf:
                tot_diff = tdf
                best_diff = diff
                best_trial = df
        else:
            if tdf < total_diff:
                if diff < best_diff:
                    best_diff = diff
                    best_trial = df
        
                if diff < zonal_difference:
                    break
        
    logger.info("    Segmented with a maximum difference of {0:,.0f} trips on a single zone".format(best_diff))
    return best_trial

# %%
demand = {}
for m in all_mats:
    mf = matrices[m].attrs.mf
    desc = matrices[m].attrs.description
    
    # We don't need to discretize most matrices
    if len(mf) > 5:
        continue
    if int(mf[2:3]) != 2 and int(mf[2:3]) != 3:
        continue
    
    if 'truck' in desc:
        continue
    
    logger.info("{}    {}   {}".format(str(mf), m, desc))
    demand[m] = str('{}-{}'.format(mf,desc ))
    mat = np.array(matrices[m])
    
    if not mat.sum():
        continue
        
    zones = mat.shape[0]
    
    df = discretize_matrix(mat, tazs)
    df.to_sql('trips', outdb, if_exists='append')
    
    logger.info("    Original Matrix: {0:,.0f}".format(mat.sum()))
    logger.info("    Result Matrix: {0:,.0f}".format(df.shape[0]))
    
matrices.close()
# Out:
# 2019-05-11 14:17:54 INFO     b'mf216'    Bk_pertrp_Am   Bike per-trips AM
# 2019-05-11 14:18:06 INFO         Segmented with a maximum difference of 11 trips on a single zone
# 2019-05-11 14:18:06 INFO         Original Matrix: 10,303
# 2019-05-11 14:18:06 INFO         Result Matrix: 10,277
# 2019-05-11 14:18:06 INFO     b'mf246'    Bk_pertrp_Md   Bike per-trips MD
# 2019-05-11 14:18:18 INFO         Segmented with a maximum difference of 10 trips on a single zone
# 2019-05-11 14:18:18 INFO         Original Matrix: 5,366
# 2019-05-11 14:18:18 INFO         Result Matrix: 5,347
# 2019-05-11 14:18:18 INFO     b'mf276'    Bk_pertrp_Pm   Bike per-trips PM
# 2019-05-11 14:18:29 INFO         Segmented with a maximum difference of 12 trips on a single zone
# 2019-05-11 14:18:30 INFO         Original Matrix: 9,868
# 2019-05-11 14:18:30 INFO         Result Matrix: 9,865
# 2019-05-11 14:18:30 INFO     b'mf306'    HOV_drvtrp_VOT_1_Am   HOV drv-trips VOT 1 AM
# 2019-05-11 14:18:57 INFO         Segmented with a maximum difference of 10 trips on a single zone
# 2019-05-11 14:18:58 INFO         Original Matrix: 33,145
# 2019-05-11 14:18:58 INFO         Result Matrix: 33,150
# 2019-05-11 14:18:58 INFO     b'mf326'    HOV_drvtrp_VOT_1_Md   HOV drv-trips VOT 1 MD
# 2019-05-11 14:19:26 INFO         Segmented with a maximum difference of 12 trips on a single zone
# 2019-05-11 14:19:26 INFO         Original Matrix: 16,891
# 2019-05-11 14:19:26 INFO         Result Matrix: 16,877
# 2019-05-11 14:19:26 INFO     b'mf346'    HOV_drvtrp_VOT_1_Pm   HOV drv-trips VOT 1 PM
# 2019-05-11 14:19:54 INFO         Segmented with a maximum difference of 11 trips on a single zone
# 2019-05-11 14:19:54 INFO         Original Matrix: 17,280
# 2019-05-11 14:19:54 INFO         Result Matrix: 17,296
# 2019-05-11 14:19:54 INFO     b'mf307'    HOV_drvtrp_VOT_2_Am   HOV drv-trips VOT 2 AM
# 2019-05-11 14:20:22 INFO         Segmented with a maximum difference of 14 trips on a single zone
# 2019-05-11 14:20:22 INFO         Original Matrix: 29,520
# 2019-05-11 14:20:22 INFO         Result Matrix: 29,565
# 2019-05-11 14:20:22 INFO     b'mf327'    HOV_drvtrp_VOT_2_Md   HOV drv-trips VOT 2 MD
# 2019-05-11 14:20:48 INFO         Segmented with a maximum difference of 12 trips on a single zone
# 2019-05-11 14:20:49 INFO         Original Matrix: 16,883
# 2019-05-11 14:20:49 INFO         Result Matrix: 16,844
# 2019-05-11 14:20:49 INFO     b'mf347'    HOV_drvtrp_VOT_2_Pm   HOV drv-trips VOT 2 PM
# 2019-05-11 14:21:15 INFO         Segmented with a maximum difference of 15 trips on a single zone
# 2019-05-11 14:21:15 INFO         Original Matrix: 30,379
# 2019-05-11 14:21:15 INFO         Result Matrix: 30,418
# 2019-05-11 14:21:15 INFO     b'mf308'    HOV_drvtrp_VOT_3_Am   HOV drv-trips VOT 3 AM
# 2019-05-11 14:21:43 INFO         Segmented with a maximum difference of 14 trips on a single zone
# 2019-05-11 14:21:43 INFO         Original Matrix: 16,047
# 2019-05-11 14:21:43 INFO         Result Matrix: 16,083
# 2019-05-11 14:21:43 INFO     b'mf328'    HOV_drvtrp_VOT_3_Md   HOV drv-trips VOT 3 MD
# 2019-05-11 14:22:10 INFO         Segmented with a maximum difference of 14 trips on a single zone
# 2019-05-11 14:22:10 INFO         Original Matrix: 14,893
# 2019-05-11 14:22:10 INFO         Result Matrix: 14,905
# 2019-05-11 14:22:10 INFO     b'mf348'    HOV_drvtrp_VOT_3_Pm   HOV drv-trips VOT 3 PM
# 2019-05-11 14:22:36 INFO         Segmented with a maximum difference of 18 trips on a single zone
# 2019-05-11 14:22:37 INFO         Original Matrix: 23,927
# 2019-05-11 14:22:37 INFO         Result Matrix: 23,913
# 2019-05-11 14:22:37 INFO     b'mf309'    HOV_drvtrp_VOT_4_Am   HOV drv-trips VOT 4 AM
# 2019-05-11 14:22:37 INFO     b'mf329'    HOV_drvtrp_VOT_4_Md   HOV drv-trips VOT 4 MD
# 2019-05-11 14:22:37 INFO     b'mf349'    HOV_drvtrp_VOT_4_Pm   HOV drv-trips VOT 4 PM
# 2019-05-11 14:22:37 INFO     b'mf206'    HOV_pertrp_VOT_1_Am   HOV per-trips VOT 1 AM
# 2019-05-11 14:23:06 INFO         Segmented with a maximum difference of 14 trips on a single zone
# 2019-05-11 14:23:07 INFO         Original Matrix: 97,482
# 2019-05-11 14:23:07 INFO         Result Matrix: 97,519
# 2019-05-11 14:23:07 INFO     b'mf236'    HOV_pertrp_VOT_1_Md   HOV per-trips VOT 1 MD
# 2019-05-11 14:23:34 INFO         Segmented with a maximum difference of 16 trips on a single zone
# 2019-05-11 14:23:34 INFO         Original Matrix: 43,171
# 2019-05-11 14:23:34 INFO         Result Matrix: 43,137
# 2019-05-11 14:23:34 INFO     b'mf266'    HOV_pertrp_VOT_1_Pm   HOV per-trips VOT 1 PM
# 2019-05-11 14:24:02 INFO         Segmented with a maximum difference of 16 trips on a single zone
# 2019-05-11 14:24:02 INFO         Original Matrix: 45,369
# 2019-05-11 14:24:02 INFO         Result Matrix: 45,343
# 2019-05-11 14:24:02 INFO     b'mf207'    HOV_pertrp_VOT_2_Am   HOV per-trips VOT 2 AM
# 2019-05-11 14:24:31 INFO         Segmented with a maximum difference of 20 trips on a single zone
# 2019-05-11 14:24:32 INFO         Original Matrix: 75,184
# 2019-05-11 14:24:32 INFO         Result Matrix: 75,167
# 2019-05-11 14:24:32 INFO     b'mf237'    HOV_pertrp_VOT_2_Md   HOV per-trips VOT 2 MD
# 2019-05-11 14:24:59 INFO         Segmented with a maximum difference of 17 trips on a single zone
# 2019-05-11 14:25:00 INFO         Original Matrix: 41,640
# 2019-05-11 14:25:00 INFO         Result Matrix: 41,649
# 2019-05-11 14:25:00 INFO     b'mf267'    HOV_pertrp_VOT_2_Pm   HOV per-trips VOT 2 PM
# 2019-05-11 14:25:29 INFO         Segmented with a maximum difference of 21 trips on a single zone
# 2019-05-11 14:25:30 INFO         Original Matrix: 76,309
# 2019-05-11 14:25:30 INFO         Result Matrix: 76,336
# 2019-05-11 14:25:30 INFO     b'mf208'    HOV_pertrp_VOT_3_Am   HOV per-trips VOT 3 AM
# 2019-05-11 14:25:57 INFO         Segmented with a maximum difference of 20 trips on a single zone
# 2019-05-11 14:25:57 INFO         Original Matrix: 32,988
# 2019-05-11 14:25:57 INFO         Result Matrix: 32,999
# 2019-05-11 14:25:57 INFO     b'mf238'    HOV_pertrp_VOT_3_Md   HOV per-trips VOT 3 MD
# 2019-05-11 14:26:24 INFO         Segmented with a maximum difference of 16 trips on a single zone
# 2019-05-11 14:26:24 INFO         Original Matrix: 28,059
# 2019-05-11 14:26:24 INFO         Result Matrix: 28,032
# 2019-05-11 14:26:24 INFO     b'mf268'    HOV_pertrp_VOT_3_Pm   HOV per-trips VOT 3 PM
# 2019-05-11 14:26:52 INFO         Segmented with a maximum difference of 21 trips on a single zone
# 2019-05-11 14:26:53 INFO         Original Matrix: 48,380
# 2019-05-11 14:26:53 INFO         Result Matrix: 48,331
# 2019-05-11 14:26:53 INFO     b'mf209'    HOV_pertrp_VOT_4_Am   HOV per-trips VOT 4 AM
# 2019-05-11 14:26:53 INFO     b'mf239'    HOV_pertrp_VOT_4_Md   HOV per-trips VOT 4 MD
# 2019-05-11 14:26:53 INFO     b'mf269'    HOV_pertrp_VOT_4_Pm   HOV per-trips VOT 4 PM
# 2019-05-11 14:26:54 INFO     b'mf300'    SOV_drvtrp_VOT_1_Am   SOV drv-trips VOT 1 AM
# 2019-05-11 14:27:21 INFO         Segmented with a maximum difference of 9 trips on a single zone
# 2019-05-11 14:27:21 INFO         Original Matrix: 8,903
# 2019-05-11 14:27:21 INFO         Result Matrix: 8,941
# 2019-05-11 14:27:21 INFO     b'mf320'    SOV_drvtrp_VOT_1_Md   SOV drv-trips VOT 1 MD
# 2019-05-11 14:27:48 INFO         Segmented with a maximum difference of 15 trips on a single zone
# 2019-05-11 14:27:48 INFO         Original Matrix: 27,778
# 2019-05-11 14:27:48 INFO         Result Matrix: 27,786
# 2019-05-11 14:27:48 INFO     b'mf340'    SOV_drvtrp_VOT_1_Pm   SOV drv-trips VOT 1 PM
# 2019-05-11 14:28:15 INFO         Segmented with a maximum difference of 13 trips on a single zone
# 2019-05-11 14:28:16 INFO         Original Matrix: 24,366
# 2019-05-11 14:28:16 INFO         Result Matrix: 24,366
# 2019-05-11 14:28:16 INFO     b'mf301'    SOV_drvtrp_VOT_2_Am   SOV drv-trips VOT 2 AM
# 2019-05-11 14:28:44 INFO         Segmented with a maximum difference of 20 trips on a single zone
# 2019-05-11 14:28:44 INFO         Original Matrix: 58,119
# 2019-05-11 14:28:44 INFO         Result Matrix: 58,071
# 2019-05-11 14:28:44 INFO     b'mf321'    SOV_drvtrp_VOT_2_Md   SOV drv-trips VOT 2 MD
# 2019-05-11 14:29:11 INFO         Segmented with a maximum difference of 16 trips on a single zone
# 2019-05-11 14:29:12 INFO         Original Matrix: 42,537
# 2019-05-11 14:29:12 INFO         Result Matrix: 42,536
# 2019-05-11 14:29:12 INFO     b'mf341'    SOV_drvtrp_VOT_2_Pm   SOV drv-trips VOT 2 PM
# 2019-05-11 14:29:40 INFO         Segmented with a maximum difference of 20 trips on a single zone
# 2019-05-11 14:29:40 INFO         Original Matrix: 68,709
# 2019-05-11 14:29:40 INFO         Result Matrix: 68,677
# 2019-05-11 14:29:40 INFO     b'mf302'    SOV_drvtrp_VOT_3_Am   SOV drv-trips VOT 3 AM
# 2019-05-11 14:30:08 INFO         Segmented with a maximum difference of 28 trips on a single zone
# 2019-05-11 14:30:09 INFO         Original Matrix: 80,531
# 2019-05-11 14:30:09 INFO         Result Matrix: 80,492
# 2019-05-11 14:30:09 INFO     b'mf322'    SOV_drvtrp_VOT_3_Md   SOV drv-trips VOT 3 MD
# 2019-05-11 14:30:38 INFO         Segmented with a maximum difference of 26 trips on a single zone
# 2019-05-11 14:30:39 INFO         Original Matrix: 78,669
# 2019-05-11 14:30:39 INFO         Result Matrix: 78,713
# 2019-05-11 14:30:39 INFO     b'mf342'    SOV_drvtrp_VOT_3_Pm   SOV drv-trips VOT 3 PM
# 2019-05-11 14:31:07 INFO         Segmented with a maximum difference of 29 trips on a single zone
# 2019-05-11 14:31:08 INFO         Original Matrix: 103,043
# 2019-05-11 14:31:08 INFO         Result Matrix: 103,017
# 2019-05-11 14:31:08 INFO     b'mf303'    SOV_drvtrp_VOT_4_Am   SOV drv-trips VOT 4 AM
# 2019-05-11 14:31:39 INFO         Segmented with a maximum difference of 27 trips on a single zone
# 2019-05-11 14:31:40 INFO         Original Matrix: 71,789
# 2019-05-11 14:31:40 INFO         Result Matrix: 71,782
# 2019-05-11 14:31:40 INFO     b'mf323'    SOV_drvtrp_VOT_4_Md   SOV drv-trips VOT 4 MD
# 2019-05-11 14:32:08 INFO         Segmented with a maximum difference of 11 trips on a single zone
# 2019-05-11 14:32:08 INFO         Original Matrix: 11,724
# 2019-05-11 14:32:08 INFO         Result Matrix: 11,749
# 2019-05-11 14:32:08 INFO     b'mf343'    SOV_drvtrp_VOT_4_Pm   SOV drv-trips VOT 4 PM
# 2019-05-11 14:32:36 INFO         Segmented with a maximum difference of 23 trips on a single zone
# 2019-05-11 14:32:36 INFO         Original Matrix: 62,236
# 2019-05-11 14:32:36 INFO         Result Matrix: 62,202
# 2019-05-11 14:32:36 INFO     b'mf200'    SOV_pertrp_VOT_1_Am   SOV per-trips VOT 1 AM
# 2019-05-11 14:33:02 INFO         Segmented with a maximum difference of 9 trips on a single zone
# 2019-05-11 14:33:02 INFO         Original Matrix: 8,903
# 2019-05-11 14:33:02 INFO         Result Matrix: 8,907
# 2019-05-11 14:33:02 INFO     b'mf230'    SOV_pertrp_VOT_1_Md   SOV per-trips VOT 1 MD
# 2019-05-11 14:33:29 INFO         Segmented with a maximum difference of 14 trips on a single zone
# 2019-05-11 14:33:29 INFO         Original Matrix: 27,778
# 2019-05-11 14:33:29 INFO         Result Matrix: 27,767
# 2019-05-11 14:33:29 INFO     b'mf260'    SOV_pertrp_VOT_1_Pm   SOV per-trips VOT 1 PM
# 2019-05-11 14:33:58 INFO         Segmented with a maximum difference of 14 trips on a single zone
# 2019-05-11 14:33:58 INFO         Original Matrix: 24,366
# 2019-05-11 14:33:58 INFO         Result Matrix: 24,332
# 2019-05-11 14:33:58 INFO     b'mf201'    SOV_pertrp_VOT_2_Am   SOV per-trips VOT 2 AM
# 2019-05-11 14:34:26 INFO         Segmented with a maximum difference of 19 trips on a single zone
# 2019-05-11 14:34:27 INFO         Original Matrix: 58,119
# 2019-05-11 14:34:27 INFO         Result Matrix: 58,149
# 2019-05-11 14:34:27 INFO     b'mf231'    SOV_pertrp_VOT_2_Md   SOV per-trips VOT 2 MD
# 2019-05-11 14:34:51 INFO         Segmented with a maximum difference of 18 trips on a single zone
# 2019-05-11 14:34:52 INFO         Original Matrix: 42,537
# 2019-05-11 14:34:52 INFO         Result Matrix: 42,551
# 2019-05-11 14:34:52 INFO     b'mf261'    SOV_pertrp_VOT_2_Pm   SOV per-trips VOT 2 PM
# 2019-05-11 14:35:18 INFO         Segmented with a maximum difference of 19 trips on a single zone
# 2019-05-11 14:35:19 INFO         Original Matrix: 68,709
# 2019-05-11 14:35:19 INFO         Result Matrix: 68,694
# 2019-05-11 14:35:19 INFO     b'mf202'    SOV_pertrp_VOT_3_Am   SOV per-trips VOT 3 AM
# 2019-05-11 14:35:44 INFO         Segmented with a maximum difference of 26 trips on a single zone
# 2019-05-11 14:35:45 INFO         Original Matrix: 77,882
# 2019-05-11 14:35:45 INFO         Result Matrix: 77,886
# 2019-05-11 14:35:45 INFO     b'mf232'    SOV_pertrp_VOT_3_Md   SOV per-trips VOT 3 MD
# 2019-05-11 14:36:09 INFO         Segmented with a maximum difference of 23 trips on a single zone
# 2019-05-11 14:36:10 INFO         Original Matrix: 63,614
# 2019-05-11 14:36:10 INFO         Result Matrix: 63,596
# 2019-05-11 14:36:10 INFO     b'mf262'    SOV_pertrp_VOT_3_Pm   SOV per-trips VOT 3 PM
# 2019-05-11 14:36:36 INFO         Segmented with a maximum difference of 28 trips on a single zone
# 2019-05-11 14:36:37 INFO         Original Matrix: 97,964
# 2019-05-11 14:36:37 INFO         Result Matrix: 97,929
# 2019-05-11 14:36:37 INFO     b'mf203'    SOV_pertrp_VOT_4_Am   SOV per-trips VOT 4 AM
# 2019-05-11 14:37:03 INFO         Segmented with a maximum difference of 23 trips on a single zone
# 2019-05-11 14:37:04 INFO         Original Matrix: 71,789
# 2019-05-11 14:37:04 INFO         Result Matrix: 71,753
# 2019-05-11 14:37:04 INFO     b'mf233'    SOV_pertrp_VOT_4_Md   SOV per-trips VOT 4 MD
# 2019-05-11 14:37:27 INFO         Segmented with a maximum difference of 12 trips on a single zone
# 2019-05-11 14:37:28 INFO         Original Matrix: 11,724
# 2019-05-11 14:37:28 INFO         Result Matrix: 11,723
# 2019-05-11 14:37:28 INFO     b'mf263'    SOV_pertrp_VOT_4_Pm   SOV per-trips VOT 4 PM
# 2019-05-11 14:37:52 INFO         Segmented with a maximum difference of 25 trips on a single zone
# 2019-05-11 14:37:54 INFO         Original Matrix: 62,236
# 2019-05-11 14:37:54 INFO         Result Matrix: 62,279
# 2019-05-11 14:37:54 INFO     b'mf316'    WCEAm   WCE Person Trips AM
# 2019-05-11 14:37:59 INFO         Segmented with a maximum difference of 9 trips on a single zone
# 2019-05-11 14:37:59 INFO         Original Matrix: 2,468
# 2019-05-11 14:37:59 INFO         Result Matrix: 2,436
# 2019-05-11 14:37:59 INFO     b'mf336'    WCEMd   WCE Person Trips MD
# 2019-05-11 14:37:59 INFO     b'mf356'    WCEPm   WCE Person Trips PM
# 2019-05-11 14:38:04 INFO         Segmented with a maximum difference of 8 trips on a single zone
# 2019-05-11 14:38:04 INFO         Original Matrix: 2,503
# 2019-05-11 14:38:04 INFO         Result Matrix: 2,526
# 2019-05-11 14:38:04 INFO     b'mf215'    Wk_pertrp_Am   Walk per-trips AM
# 2019-05-11 14:38:09 INFO         Segmented with a maximum difference of 10 trips on a single zone
# 2019-05-11 14:38:10 INFO         Original Matrix: 65,126
# 2019-05-11 14:38:10 INFO         Result Matrix: 65,142
# 2019-05-11 14:38:10 INFO     b'mf245'    Wk_pertrp_Md   Walk per-trips MD
# 2019-05-11 14:38:14 INFO         Segmented with a maximum difference of 10 trips on a single zone
# 2019-05-11 14:38:15 INFO         Original Matrix: 31,128
# 2019-05-11 14:38:15 INFO         Result Matrix: 31,143
# 2019-05-11 14:38:15 INFO     b'mf275'    Wk_pertrp_Pm   Walk per-trips PM
# 2019-05-11 14:38:20 INFO         Segmented with a maximum difference of 12 trips on a single zone
# 2019-05-11 14:38:21 INFO         Original Matrix: 43,001
# 2019-05-11 14:38:21 INFO         Result Matrix: 43,004
# 2019-05-11 14:38:21 INFO     b'mf314'    busAm   Bus Person Trips AM
# 2019-05-11 14:38:32 INFO         Segmented with a maximum difference of 16 trips on a single zone
# 2019-05-11 14:38:33 INFO         Original Matrix: 35,799
# 2019-05-11 14:38:33 INFO         Result Matrix: 35,827
# 2019-05-11 14:38:33 INFO     b'mf334'    busMd   Bus Person Trips MD
# 2019-05-11 14:38:44 INFO         Segmented with a maximum difference of 16 trips on a single zone
# 2019-05-11 14:38:45 INFO         Original Matrix: 17,425
# 2019-05-11 14:38:45 INFO         Result Matrix: 17,382
# 2019-05-11 14:38:45 INFO     b'mf354'    busPm   Bus Person Trips PM
# 2019-05-11 14:38:56 INFO         Segmented with a maximum difference of 17 trips on a single zone
# 2019-05-11 14:38:57 INFO         Original Matrix: 32,581
# 2019-05-11 14:38:57 INFO         Result Matrix: 32,600
# 2019-05-11 14:38:57 INFO     b'mf315'    railAm   Rail Person Trips AM
# 2019-05-11 14:39:12 INFO         Segmented with a maximum difference of 21 trips on a single zone
# 2019-05-11 14:39:15 INFO         Original Matrix: 41,232
# 2019-05-11 14:39:15 INFO         Result Matrix: 41,196
# 2019-05-11 14:39:15 INFO     b'mf335'    railMd   Rail Person Trips MD
# 2019-05-11 14:39:29 INFO         Segmented with a maximum difference of 17 trips on a single zone
# 2019-05-11 14:39:30 INFO         Original Matrix: 16,367
# 2019-05-11 14:39:30 INFO         Result Matrix: 16,377
# 2019-05-11 14:39:30 INFO     b'mf355'    railPm   Rail Person Trips PM
# 2019-05-11 14:39:43 INFO         Segmented with a maximum difference of 24 trips on a single zone
# 2019-05-11 14:39:45 INFO         Original Matrix: 42,382
# 2019-05-11 14:39:45 INFO         Result Matrix: 42,339
